# %%
import os
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import seaborn as sns
import geopandas as gpd
import pandas as pd
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

import cartopy.crs as ccrs
from cartopy.crs import PlateCarree as plate
import cartopy.io.shapereader as shpreader

import xarray as xr
import atlite

import logging
import warnings

warnings.simplefilter('ignore')
logging.captureWarnings(False)
logging.basicConfig(level=logging.INFO)

# %%
shpfilename = shpreader.natural_earth(resolution='10m',
                                      category='cultural',
                                      name='admin_0_map_subunits')
reader = shpreader.Reader(shpfilename)
Galapagos = gpd.GeoSeries({r.attributes['NAME_EN']: r.geometry
                      for r in reader.records()},
                     crs={'init': 'epsg:4326'}
                     ).reindex(['Galápagos Province'])
pd.options.display.max_seq_items = 355
print(gpd.GeoSeries({r.attributes['NAME_EN']: r.geometry
                      for r in reader.records()},
                     crs={'init': 'epsg:4326'}
                     ).index)
print(Galapagos)
# Out:
# Index(['Indonesia', 'Malaysia', 'Chile', 'Bolivia', 'Peru', 'Argentina',
#        'Dhekelia Cantonment', 'Cyprus', 'India', 'People's Republic of China',
#        'Israel', 'Gaza Strip', 'West Bank', 'Lebanon', 'Ethiopia',
#        'South Sudan', 'Puntland', 'Somalia', 'Kenya', 'Malawi', 'Tanzania',
#        'United Nations Disengagement Observer Force', 'Somaliland',
#        'French Guiana', 'Suriname', 'Guyana', 'Korean Demilitarized Zone',
#        'Morocco', 'Western Sahara', 'Costa Rica', 'Nicaragua',
#        'Republic of the Congo', 'Democratic Republic of the Congo', 'Bhutan',
#        'Ukraine', 'Belarus', 'Namibia', 'South Africa', 'Syria',
#        'Saint Martin', 'Sint Maarten', 'Oman', 'Uzbekistan', 'Kazakhstan',
#        'Tajikistan', 'Lithuania', 'Brazil', 'Uruguay', 'Mongolia', 'Russia',
#        'Czech Republic', 'Germany', 'Estonia', 'Latvia', 'Norway', 'Sweden',
#        'Finland', 'Vietnam', 'Cambodia', 'Luxembourg', 'United Arab Emirates',
#        'France', 'Flemish Brabant', 'Walloon Brabant', 'Georgia',
#        'North Macedonia', 'Albania', 'Azerbaijan', 'Kosovo', 'Turkey',
#        'Adjara', 'Ceuta', 'Laos', 'Kyrgyzstan', 'Armenia', 'Denmark', 'Libya',
#        'Tunisia', 'Romania', 'Hungary', 'Slovakia', 'Poland', 'Ireland',
#        'Northern Ireland', 'Greece', 'Zambia', 'Sierra Leone', 'Guinea',
#        'Liberia', 'Central African Republic', 'Sudan', 'Djibouti', 'Eritrea',
#        'Austria', 'Kurdistan Region', 'Italy', 'Switzerland', 'Iran',
#        'Netherlands', 'Liechtenstein', 'Ivory Coast', 'Vojvodina', 'Mali',
#        'Senegal', 'Nigeria', 'Benin', 'Angola', 'Croatia', 'Slovenia', 'Qatar',
#        'Saudi Arabia', 'Botswana', 'Zimbabwe', 'Pakistan', 'Bulgaria',
#        'Thailand', 'Melilla', 'San Marino', 'Haiti', 'Dominican Republic',
#        'Chad', 'Kuwait', 'Iraq', 'El Salvador', 'Guatemala',
#        'Pante Makassar Subdistrict', 'East Timor', 'Brunei', 'Monaco',
#        'Algeria', 'Mozambique', 'Eswatini', 'Burundi', 'Rwanda', 'Myanmar',
#        'Bangladesh', 'Spain', 'Andorra', 'Afghanistan', 'Serbia', 'Montenegro',
#        'Federation of Bosnia and Herzegovina', 'Republika Srpska', 'Uganda',
#        'Guantanamo Bay Naval Base', 'Cuba', 'Honduras', 'Ecuador', 'Colombia',
#        'Paraguay', 'Brazilian Island', 'Portugal', 'Brčko', 'Moldova',
#        'Kaliningrad Oblast', 'North Korea', 'Turkmenistan', 'Jordan', 'Nepal',
#        'Lesotho', 'Cameroon', 'Gabon', 'Niger', 'Burkina Faso', 'Togo',
#        'Ghana', 'Guinea-Bissau', 'Gibraltar', 'United States of America',
#        'Canada', 'Mexico', 'Belize', 'Panama', 'Venezuela', 'Papua New Guinea',
#        'Egypt', 'Yemen', 'Mauritania', 'Río Muni', 'The Gambia', 'Alaska',
#        'Hong Kong', 'Vatican City', 'Turkish Republic of Northern Cyprus',
#        'United Nations Buffer Zone in Cyprus', 'Siachen Glacier',
#        'South Korea', 'Baikonur', 'Akrotiri Sovereign Base Area',
#        'Southern Patagonian Ice Field', 'Autonomous Republic of Crimea',
#        'Bir Tawil', 'Wales', 'England', 'Scotland', 'Brussels Capital Region',
#        'Antarctica', 'Australia', 'Greenland', 'Fiji',
#        'New Zealand Subantarctic Islands', 'Isla Salas y Gómez',
#        'Easter Island', 'New Caledonia', 'Madagascar', 'Galápagos Province',
#        'Philippines', 'Sri Lanka', 'Curaçao', 'Aruba', 'Hainan', 'The Bahamas',
#        'Turks and Caicos Islands', 'Taiwan', 'Japan', 'Kyushu', 'Shikoku',
#        'Honshu', 'Hokkaido Prefecture', 'Saint Pierre and Miquelon', 'Iceland',
#        'South Orkney Islands', 'Pitcairn Islands', 'French Polynesia',
#        'Juan de Nova Island', 'Seychelles', 'Kiribati', 'Marshall Islands',
#        'Lakshadweep', 'Trinidad', 'Tobago', 'Grenada', 'Andaman Islands',
#        'Caribbean Netherlands', 'Saint Vincent and the Grenadines', 'Barbados',
#        'Saint Lucia', 'Martinique', 'Dominica', 'Guadeloupe', 'Johnston Atoll',
#        'Montserrat', 'Antigua', 'Saint Kitts and Nevis', 'Barbuda',
#        'United States Virgin Islands', 'Saint Barthélemy', 'Puerto Rico',
#        'Anguilla', 'British Virgin Islands', 'Jamaica', 'Cayman Islands',
#        'Bermuda', 'Heard Island and McDonald Islands', 'Prince Edward Islands',
#        'Tristan da Cunha', 'Réunion', 'Mauritius', 'Saint Helena', 'Mayotte',
#        'Comoros', 'Ascension', 'Zanzibar', 'Annobón Province',
#        'São Tomé Island', 'Príncipe', 'Bioko', 'Cape Verde', 'Canary Islands',
#        'Madeira', 'Malta', 'Pantelleria Island', 'Azores', 'Sicily',
#        'Balearic Islands', 'Sardinia', 'Corsica', 'Jersey', 'Guernsey',
#        'Isle of Man', 'Bornholm', 'Åland', 'Faroe Islands', 'Tasmania',
#        'Cocos', 'Diego Garcia Navy Airport', 'Singapore', 'Nicobar Islands',
#        'Hawaii', 'Ryukyu Islands', 'Volcano Islands', 'Ogasawara Islands',
#        'Izu Islands', 'Jeju Province', 'Ulleungdo', 'Baengnyeongdo',
#        'Jan Mayen', 'Svalbard', 'Macquarie Island', 'Chatham Islands',
#        'Kermadec Islands', 'Norfolk Island', 'Cook Islands', 'Tonga',
#        'Wallis and Futuna', 'Samoa', 'Solomon Islands', 'Tuvalu',
#        'British Indian Ocean Territory', 'Autonomous Region of Bougainville',
#        'Maldives', 'Nauru', 'Federated States of Micronesia',
#        'South Sandwich Islands', 'South Georgia', 'Bouvet Island',
#        'Falkland Islands', 'Vanuatu', 'Niue', 'American Samoa', 'Palau',
#        'Socotra Archipelago', 'Guam', 'Northern Mariana Islands',
#        'Paracel Islands', 'Bahrain', 'Europa Island', 'Coral Sea Islands',
#        'Christmas Island', 'Tokelau', 'Jarvis Island', 'Baker Island',
#        'Howland Island', 'Wake Island', 'Midway Atoll', 'Pelagie Islands',
#        'Sark', 'Alderney', 'Peter I Island', 'Clipperton Island',
#        'Navassa Island', 'Macau', 'South Island', 'North Island',
#        'Bassas da India', 'Tromelin Island', 'Ashmore and Cartier Islands',
#        'Glorioso Islands', 'Palmyra Atoll', 'Kingman Reef', 'Bajo Nuevo Bank',
#        'Serranilla Bank', 'Herm', 'Liancourt Rocks', 'Scarborough Shoal'],
#       dtype='object')
# Galápagos Province    MULTIPOLYGON (((-89.66128 -1.34010, -89.63467 ...
# dtype: geometry

# %%
# Define the cutout; this will not yet trigger any major operations
cutout = atlite.Cutout(path="galapagos-2011-01",
                       module="era5",
                       x=slice(-91.7, -89.1),
                       y=slice(-1.6, 0.69),
                       time="2011-01")

# This is where all the work happens (this can take some time, for us it took ~15 minutes).
cutout.prepare()
# Out:
# INFO:atlite.data:Cutout already prepared.
# <Cutout "galapagos-2011-01">
#  x = -91.50 ⟷ -89.25, dx = 0.25
#  y = -1.50 ⟷ 0.50, dy = 0.25
#  time = 2011-01-01 ⟷ 2011-01-31, dt = H
#  module = era5
#  prepared_features = ['height', 'wind', 'influx', 'temperature', 'runoff']

# %%
cells = cutout.grid
df = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
country_bound = gpd.GeoSeries(cells.unary_union)

projection = ccrs.Orthographic(-90, -1)
fig, ax = plt.subplots(subplot_kw={'projection': projection}, figsize=(6, 6))
df.plot(ax=ax, transform=plate())
country_bound.plot(ax=ax, edgecolor='orange',
                   facecolor='None', transform=plate())
fig.tight_layout()

# %%
fig = plt.figure(figsize=(12, 7))
gs = GridSpec(3, 3, figure=fig)

ax = fig.add_subplot(gs[:, 0:2], projection=projection)
plot_grid_dict = dict(alpha=0.1, edgecolor='k', zorder=4, aspect='equal',
                      facecolor='None', transform=plate())
Galapagos.plot(ax=ax, zorder=1, transform=plate())
cells.plot(ax=ax, **plot_grid_dict)
country_bound.plot(ax=ax, edgecolor='orange',
                   facecolor='None', transform=plate())
# ax.outline_patch.set_edgecolor('white')

ax1 = fig.add_subplot(gs[0, 2])
cutout.data.wnd100m.mean(['x', 'y']).plot(ax=ax1)
ax1.set_frame_on(False)
ax1.xaxis.set_visible(False)

ax2 = fig.add_subplot(gs[1, 2], sharex=ax1)
cutout.data.influx_direct.mean(['x', 'y']).plot(ax=ax2)
ax2.set_frame_on(False)
ax2.xaxis.set_visible(False)

ax3 = fig.add_subplot(gs[2, 2], sharex=ax1)
cutout.data.runoff.mean(['x', 'y']).plot(ax=ax3)
ax3.set_frame_on(False)
ax3.set_xlabel(None)

fig.tight_layout()

# %%
cap_factors = cutout.wind(turbine='Vestas_V112_3MW', capacity_factor=True)

fig, ax = plt.subplots(subplot_kw={'projection': projection}, figsize=(9, 7))
Galapagos.plot(ax=ax, zorder=1, transform=plate())
cap_factors.name = 'Capacity Factor'
cap_factors.plot(ax=ax, transform=plate(), alpha=0.8)
cells.plot(ax=ax, **plot_grid_dict)
# ax.outline_patch.set_edgecolor('white')
fig.tight_layout()
# Out:
# INFO:atlite.convert:Convert and aggregate 'wind'.

# %%
cap_factors = cutout.pv(panel="CSi", orientation={'slope': 30., 'azimuth': 180.}, capacity_factor=True)

fig, ax = plt.subplots(subplot_kw={'projection': projection}, figsize=(9, 7))
Galapagos.plot(ax=ax, zorder=1, transform=plate())
cap_factors.name = 'Capacity Factor'
cap_factors.plot(ax=ax, transform=plate(), alpha=0.8)
cells.plot(ax=ax, **plot_grid_dict)
# ax.outline_patch.set_edgecolor('white')
fig.tight_layout()
# Out:
# INFO:atlite.convert:Convert and aggregate 'pv'.
